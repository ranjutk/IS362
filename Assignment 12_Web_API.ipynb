# %% [markdown]
# # Assignment 12- Web API

# %% [markdown]
# Importing all the required libraries

# %%
import urllib.request
import json
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# After loggging to developer NYT account I was able to get an API from NYTimes Api page
# I am looking into the movie reviews from critics.

# %%
key = '40e90f1194ce41088e59f375892b7683'
web_url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'

request = web_url+'&api-key='+key
response = str(urllib.request.urlopen(request).read(), 'utf-8')

movie = json.loads(response)
movie
# Out:
# {'copyright': 'Copyright (c) 2018 The New York Times Company. All Rights Reserved.',
#  'has_more': True,
#  'num_results': 20,
#  'results': [{'byline': 'GLENN KENNY',
#    'critics_pick': 1,
#    'date_updated': '2018-11-08 12:04:10',
#    'display_title': 'Infinite Football',
#    'headline': '‘Infinite Football’ Review: Soccer and Other Existential Questions',
#    'link': {'suggested_link_text': 'Read the New York Times Review of Infinite Football',
#     'type': 'article',
#     'url': 'http://www.nytimes.com/2018/11/08/movies/infinite-football-review-documentary.html'},
#    'mpaa_rating': '',
#    'multimedia': {'height': 140,
#     'src': 'https://static01.nyt.com/images/2018/11/09/arts/09infinite/merlin_146195229_63dc9e1c-787f-494c-b22f-2b268bf83a85-mediumThreeByTwo210.jpg',
#     'type': 'mediumThreeByTwo210',
#     'width': 210},
#    'opening_date': '2018-11-09',
#    'publication_date': '2018-11-08',
# ...

# %% [markdown]
# This is the json we got back from the API response for movie critics reviews.
# Now adding this into the panda dataframe.

# %%
df = pd.DataFrame(data=movie['results'])
df.head(10)
# Out:
#                 byline  critics_pick         date_updated  \
# 0          GLENN KENNY             1  2018-11-08 12:04:10
# 1  JEANNETTE CATSOULIS             1  2018-11-08 12:04:07
# 2       KEN JAWOROWSKI             1  2018-11-13 03:44:20
# 3           A.O. SCOTT             1  2018-11-12 17:44:01
# 4       MANOHLA DARGIS             0  2018-11-13 03:44:24
# 5          BILGE EBIRI             0  2018-11-13 03:44:24
# 6       MANOHLA DARGIS             0  2018-11-13 03:44:24
# 7           TEO BUGBEE             0  2018-11-13 03:44:23
# 8         AISHA HARRIS             0  2018-11-13 03:44:23
# 9  JEANNETTE CATSOULIS             0  2018-11-13 03:44:23
#
#                                  display_title  \
# 0                            Infinite Football
# 1                                    Number 37
# 2                                   Weightless
# 3                 The Ballad of Buster Scruggs
# 4  Fantastic Beasts: The Crimes of Grindelwald
# ...
